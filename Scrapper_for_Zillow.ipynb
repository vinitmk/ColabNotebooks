# %% [markdown]
# ## **`Web Scrapper`**
# #### Zillow - Reading a list of addresses from a google sheet and scrapping additional details on each property from zillow.com

# %%
pip install unicodecsv
# Out:
# Collecting unicodecsv
#   Downloading https://files.pythonhosted.org/packages/6f/a4/691ab63b17505a26096608cc309960b5a6bdf39e4ba1a793d5f9b1a53270/unicodecsv-0.14.1.tar.gz
# Building wheels for collected packages: unicodecsv
#   Building wheel for unicodecsv (setup.py) ... done
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-cp36-none-any.whl size=10769 sha256=18407fc26038a3c174894d413d2307009fe3e5e6d37e23abd8584a7b3386ea77
#   Stored in directory: /root/.cache/pip/wheels/a6/09/e9/e800279c98a0a8c94543f3de6c8a562f60e51363ed26e71283
# Successfully built unicodecsv
# Installing collected packages: unicodecsv
# Successfully installed unicodecsv-0.14.1

# %%
"""**Import all the libraries**"""

from lxml import html
import requests
import unicodecsv as csv
import argparse
import json
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
from collections import OrderedDict
import pandas as pd
from io import BytesIO
import requests

# %%
r = requests.get('https://docs.google.com/spreadsheets/d/e/2PACX-1vQgYTKQBRlL6cYPL3PuaIDH03Hdbohycj8Y_thlLwkEV0ZFMnQBWVJYY9_Q8HEHfi3jxWXPWQKhmWB8/pub?output=tsv')
df = pd.read_csv(BytesIO(r.content), sep='\t')
df.columns

fulladdress = df["Full Address"] +" "+ df["Zip"].map(str)
mlsDF = df["MLS #"]

print(fulladdress)
print(mlsDF)
fulladdress.shape

fulladdress = fulladdress.str.replace('  ',' ')
fulladdress = fulladdress.str.replace(' ','-')
print(fulladdress.head)
# Out:
# 0       4095 Bonita Road  132 91902
# 1           88 Fourth Ave  10 91910
# 2      2167 Palo Alto Dr  133 91914
# 3        2134 Cantata Dr.  36 91914
# 4        280 Salinas Dr.  171 91914
#                    ...
# 242         7019 DEERHURST CT 92139
# 243          2233 Manzana Way 92139
# 244    24374 Larchmont Ct  69 92653
# 245       25185 Via Terracina 92677
# 246      3575 Cameo Drive  43 92056
# Length: 247, dtype: object
# 0      180045508
# 1      180024056
# 2      180035693
# 3      180042493
# 4      180038189
#          ...
# 242    180044441
# 243    180044784
# 244    180040324
# 245    180042450
# 246    180035417
# Name: MLS #, Length: 247, dtype: int64
# <bound method NDFrame.head of 0       4095-Bonita-Road-132-91902
# 1           88-Fourth-Ave-10-91910
# 2      2167-Palo-Alto-Dr-133-91914
# 3        2134-Cantata-Dr.-36-91914
# 4        280-Salinas-Dr.-171-91914
#                   ...
# 242        7019-DEERHURST-CT-92139
# 243         2233-Manzana-Way-92139
# 244    24374-Larchmont-Ct-69-92653
# 245      25185-Via-Terracina-92677
# 246      3575-Cameo-Drive-43-92056
# Length: 247, dtype: object>

# %%
def clean(text):
    if text:
        return ' '.join(' '.join(text).split())
    return None

def get_headers():
    # Creating headers.
    headers = {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
               'accept-encoding': 'gzip, deflate, sdch, br',
               'accept-language': 'en-GB,en;q=0.8,en-US;q=0.6,ml;q=0.4',
               'cache-control': 'max-age=0',
               'upgrade-insecure-requests': '1',
               'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36'}
    return headers

def create_url(address):
    url = "https://www.zillow.com/homes/"+address+"_rb/"
    print(url)
    return url

def save_to_file(response):
    # saving response to `response.html`

    with open("response.html", 'w') as fp:
        fp.write(response.text)

def write_data_to_csv(data):
    # saving scraped data to csv.

    with open("properties-%s.csv" % ('final'), 'wb') as csvfile:
        fieldnames = ['MLS #', 'HOA', 'Zestimate', 'Sold', 'Sold On', 'Rent Estimate', 
                      'Mortgage', 'Walk Score', 'Transit Score', 'Neighborhood', 
                      'Neighborhood Change In Price', 'Neighborhood Predicted Change','Neighborhood Median Price']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for row in data:
            writer.writerow(row)

def get_response(url):
    # Getting response from zillow.com.

    for i in range(5):
        response = requests.get(url, headers=get_headers())
        print("status code received:", response.status_code)
        if response.status_code != 200:
            # saving response to file for debugging purpose.
            save_to_file(response)
            continue
        else:
            save_to_file(response)
            return response
    return None

def parse(mls, address):
    url = create_url(address)
    response = get_response(url)

    if not response:
        print("Failed to fetch the page, please check `response.html` to see the response received from zillow.com.")
        return None

    # These two new lines are added
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urlopen(req).read()
    parser = html.fromstring(webpage)

    #overview = parser.xpath("//*[@id='ds-data-view']/ul/li[4]/div[1]/div/div[1]/div[1]/div//text()")
    #print(overview)
    hoa = parser.xpath("//*[@id='ds-data-view']/ul/li[4]/div[2]/div/div[1]/ul/li[6]/span[2]//text()")
    #print('hoa ', hoa)
    zestimate = parser.xpath("//*[@id='ds-container']/div[4]/div[2]/div/p/span[3]/span[2]/span[2]//text()")
    #print('Zestimate ', zestimate)
    sold = parser.xpath("//*[@id='ds-container']/div[4]/div[2]/div/p/span[1]/span[2]/text()[2]")
    #print('Sold Price ', sold)
    soldOn = parser.xpath("//*[@id='ds-container']/div[4]/div[2]/div/p/span[2]/text()[2]")
    #print('Sold On', soldOn)
    rentEstimate = parser.xpath("//*[@id='ds-data-view']/ul/li[3]/div[2]/div[1]/div[1]/div[3]/p[1]/span//text()")
    #print('Rent Estimate', rentEstimate)
    mortgage = parser.xpath("//*[@id='ds-data-view']/ul/li[3]/div[2]/div[1]/div[2]/div[3]/p[1]/span//text()")
    #print('Mortgage ', mortgage)
    walkScore = parser.xpath("//*[@class='ds-data-view']/ul/li[5]/div[1]/div[1]/div/ul/li[2]/a/span//text()")
    #print('Walk Score 11 ', walkScore)
    transitScore = parser.xpath("//*[@id='ds-data-view']/ul/li[5]/div[1]/div[1]/div/ul/li[2]/span[2]/text()[2]")
    #print('Transit Score ', transitScore)
    changeInPastYear1 = parser.xpath("//*[@id='ds-data-view']/ul/li[5]/div[1]/div[1]/ul/li[1]/p/span/text()[1]")
    changeInPastYear2 = parser.xpath("//*[@id='ds-data-view']/ul/li[5]/div[1]/div[1]/ul/li[1]/p/span/text()[2]") 
    changeInPastYear = changeInPastYear1 + changeInPastYear2
    #print("changeInPastYear ", changeInPastYear)
    expectedChangeInValue1 = parser.xpath("//*[@id='ds-data-view']/ul/li[5]/div[1]/div[1]/ul/li[2]/p/span/text()[1]")
    expectedChangeInValue2 = parser.xpath("//*[@id='ds-data-view']/ul/li[5]/div[1]/div[1]/ul/li[2]/p/span/text()[3]")
    expectedChangeInValue = expectedChangeInValue1 + expectedChangeInValue2
    #print("expectedChangeInValue ", expectedChangeInValue)
    neighborhood = parser.xpath("//*[@id='ds-container']/div[4]/div[2]/div/div[1]/header/h1/span[2]/text()[2]")
    #print("neighborhood ", neighborhood)
    neighborhoodMedianPrice = parser.xpath("//*[@id='ds-data-view']/ul/li[5]/div[1]/div[1]/ul/li[4]/p/text()[4]")
    #print("neighborhoodMedianPrice ", neighborhoodMedianPrice)

    # soup = BeautifulSoup(r.content, 'html.parser')
    # property_data = OrderedDict()
    # title_list = soup.findAll('span', {'class': 'Text-aiai24-0'})
    # print(title_list)
    # property_data['walkScore'] = soup.find('span', attrs={'class': 'ds-container'})
    # print("property_data['walkScore'] ", property_data['walkScore']) 

    #properties_list = []
    properties = {
                  'MLS #' : mls,
                  'HOA' : clean(hoa),
                  'Zestimate' : clean(zestimate),
                  'Sold' : clean(sold),
                  'Sold On': clean(soldOn),
                  'Rent Estimate' : clean(rentEstimate),
                  'Mortgage': clean(mortgage),
                  'Walk Score': clean(walkScore),
                  'Transit Score' : clean(transitScore),
                  'Neighborhood' : clean(neighborhood),
                  'Neighborhood Change In Price' : clean(changeInPastYear),
                  'Neighborhood Predicted Change' : clean(expectedChangeInValue),
                  'Neighborhood Median Price' : clean(neighborhoodMedianPrice)
    }
    return properties

# %%
properties_list = []

for i in fulladdress.index:
   print(mlsDF[i], fulladdress[i])
   scraped_data = parse(mlsDF[i], fulladdress[i])
   properties_list.append(scraped_data)

if properties_list:
  print ("Writing data to output file")
write_data_to_csv(properties_list)
# Out:
# 180045508 4095-Bonita-Road-132-91902
# https://www.zillow.com/homes/4095-Bonita-Road-132-91902_rb/
# status code received: 200
# 180024056 88-Fourth-Ave-10-91910
# https://www.zillow.com/homes/88-Fourth-Ave-10-91910_rb/
# status code received: 200
# 180035693 2167-Palo-Alto-Dr-133-91914
# https://www.zillow.com/homes/2167-Palo-Alto-Dr-133-91914_rb/
# status code received: 200
# 180042493 2134-Cantata-Dr.-36-91914
# https://www.zillow.com/homes/2134-Cantata-Dr.-36-91914_rb/
# status code received: 200
# 180038189 280-Salinas-Dr.-171-91914
# https://www.zillow.com/homes/280-Salinas-Dr.-171-91914_rb/
# status code received: 200
# 180043165 2360-Corte-Pescado-88-91914
# https://www.zillow.com/homes/2360-Corte-Pescado-88-91914_rb/
# status code received: 200
# 180045558 2340-Corte-Flores-98-91914
# https://www.zillow.com/homes/2340-Corte-Flores-98-91914_rb/
# status code received: 200
# 180037792 2271-Alicante-Cove-91914
# https://www.zillow.com/homes/2271-Alicante-Cove-91914_rb/
# status code received: 200
# 180040474 381-Caminito-Barcelona-59-91914
# https://www.zillow.com/homes/381-Caminito-Barcelona-59-91914_rb/
# status code received: 200
# 180043088 4416-Palm-Ave-11-91941
# https://www.zillow.com/homes/4416-Palm-Ave-11-91941_rb/
# status code received: 200
# 180042646 4412-Palm-Ave.-2-91941
# https://www.zillow.com/homes/4412-Palm-Ave.-2-91941_rb/
# status code received: 200
# 180042673 4414-Palm-Ave.-3-91941
# https://www.zillow.com/homes/4414-Palm-Ave.-3-91941_rb/
# status code received: 200
# 180041627 3880-Murray-Hill-Rd-91941
# https://www.zillow.com/homes/3880-Murray-Hill-Rd-91941_rb/
# status code received: 200
# 180039455 5700-Baltimore-Dr-71-91942
# https://www.zillow.com/homes/5700-Baltimore-Dr-71-91942_rb/
# status code received: 200
# 180038866 5700-Baltimore-Dr-241-91942
# https://www.zillow.com/homes/5700-Baltimore-Dr-241-91942_rb/
# status code received: 200
# 180028390 7002-Melody-Ln-91942
# https://www.zillow.com/homes/7002-Melody-Ln-91942_rb/
# status code received: 200
# 180041277 7780-Parkway-Dr-1001-91942
# https://www.zillow.com/homes/7780-Parkway-Dr-1001-91942_rb/
# status code received: 200
# 180045667 7705-El-Cajon-Boulevard-1-91942
# https://www.zillow.com/homes/7705-El-Cajon-Boulevard-1-91942_rb/
# status code received: 200
# 180042650 7715-El-Cajon-Blvd-5-91942
# https://www.zillow.com/homes/7715-El-Cajon-Blvd-5-91942_rb/
# status code received: 200
# 180032956 5440-Baltimore-Drive-157-91942
# https://www.zillow.com/homes/5440-Baltimore-Drive-157-91942_rb/
# status code received: 200
# 180035282 3605-Grove-Street-156-91945
# https://www.zillow.com/homes/3605-Grove-Street-156-91945_rb/
# status code received: 200
# 180037811 3525-Grove-St-116-91945
# https://www.zillow.com/homes/3525-Grove-St-116-91945_rb/
# status code received: 200
# 180031531 3180-Florine-Dr-4-91945
# https://www.zillow.com/homes/3180-Florine-Dr-4-91945_rb/
# status code received: 200
# 180044672 1925-Via-Las-Palmas-42-91950
# https://www.zillow.com/homes/1925-Via-Las-Palmas-42-91950_rb/
# status code received: 200
# 180042049 3328-Fairlomas-Rd-91950
# https://www.zillow.com/homes/3328-Fairlomas-Rd-91950_rb/
# status code received: 200
# 180018960 825-C-AVE-91950
# https://www.zillow.com/homes/825-C-AVE-91950_rb/
# status code received: 200
# 180041632 2108-Kings-View-Cir-91977
# https://www.zillow.com/homes/2108-Kings-View-Cir-91977_rb/
# status code received: 200
# 180036336 8109-Paradise-Valley-Ct-91977
# https://www.zillow.com/homes/8109-Paradise-Valley-Ct-91977_rb/
# status code received: 200
# 180040957 430-Bluffview-91977
# https://www.zillow.com/homes/430-Bluffview-91977_rb/
# status code received: 200
# 180031944 8164-Paradise-Valley-Court-91977
# https://www.zillow.com/homes/8164-Paradise-Valley-Court-91977_rb/
# status code received: 200
# 180041867 8233-WARMWOOD-AVE-91977
# https://www.zillow.com/homes/8233-WARMWOOD-AVE-91977_rb/
# status code received: 200
# 180019331 2037-Terraspiro-91977
# https://www.zillow.com/homes/2037-Terraspiro-91977_rb/
# status code received: 200
# 180030132 2033-Terraspiro-Ave-91977
# https://www.zillow.com/homes/2033-Terraspiro-Ave-91977_rb/
# status code received: 200
# 180030431 8737-Spring-Canyon-Dr-91977
# https://www.zillow.com/homes/8737-Spring-Canyon-Dr-91977_rb/
# status code received: 200
# 180041854 2043-Sweetwater-Rd.-B-91977
# https://www.zillow.com/homes/2043-Sweetwater-Rd.-B-91977_rb/
# status code received: 200
# 180044377 8781-Vista-Del-Oro-Way-91977
# https://www.zillow.com/homes/8781-Vista-Del-Oro-Way-91977_rb/
# status code received: 200
# 180043835 4007-Layang-Layang-Cir-F-92008
# https://www.zillow.com/homes/4007-Layang-Layang-Cir-F-92008_rb/
# status code received: 200
# 180043791 4014-Aquila-St-E-92008
# https://www.zillow.com/homes/4014-Aquila-St-E-92008_rb/
# status code received: 200
# 180043401 6909-Quail-Place-E-92009
# https://www.zillow.com/homes/6909-Quail-Place-E-92009_rb/
# status code received: 200
# 180046081 3045-Corte-Trabuco-92009
# https://www.zillow.com/homes/3045-Corte-Trabuco-92009_rb/
# status code received: 200
# 180039731 3463-Caminito-Sierra-101-92009
# https://www.zillow.com/homes/3463-Caminito-Sierra-101-92009_rb/
# status code received: 200
# 180031434 2625-Pirineos-Way-129-92009
# https://www.zillow.com/homes/2625-Pirineos-Way-129-92009_rb/
# status code received: 200
# 180042945 6175-Paseo-Camas-92009
# https://www.zillow.com/homes/6175-Paseo-Camas-92009_rb/
# status code received: 200
# 180035181 2348-La-Costa-Ave-306-92009
# https://www.zillow.com/homes/2348-La-Costa-Ave-306-92009_rb/
# status code received: 200
# 180031338 3168-Camino-Arroyo-92009
# https://www.zillow.com/homes/3168-Camino-Arroyo-92009_rb/
# status code received: 200
# 180046084 7347-Alicante-Rd-B-92009
# https://www.zillow.com/homes/7347-Alicante-Rd-B-92009_rb/
# status code received: 200
# 180045489 2349-Caringa-Way-2-92009
# https://www.zillow.com/homes/2349-Caringa-Way-2-92009_rb/
# status code received: 200
# 180040716 3146-Vista-Grande-92009
# https://www.zillow.com/homes/3146-Vista-Grande-92009_rb/
# status code received: 200
# 180037619 6279-Citracado-Cir-92009
# https://www.zillow.com/homes/6279-Citracado-Cir-92009_rb/
# status code received: 200
# 180022716 3125-Calle-Viento-92009
# https://www.zillow.com/homes/3125-Calle-Viento-92009_rb/
# status code received: 200
# 180040040 2501-Navarra-Drive-114-92009
# https://www.zillow.com/homes/2501-Navarra-Drive-114-92009_rb/
# status code received: 200
# 180034341 7578-Gibraltar-Street-7-92009
# https://www.zillow.com/homes/7578-Gibraltar-Street-7-92009_rb/
# status code received: 200
# 180040188 6261-Citracado-Circle-92009
# https://www.zillow.com/homes/6261-Citracado-Circle-92009_rb/
# status code received: 200
# 180042365 6306-Citracado-Cir-92009
# https://www.zillow.com/homes/6306-Citracado-Cir-92009_rb/
# status code received: 200
# 180038460 7095-Estrella-De-Mar-Rd-B-92009
# https://www.zillow.com/homes/7095-Estrella-De-Mar-Rd-B-92009_rb/
# status code received: 200
# 180035240 3168-Vista-Grande-92009
# https://www.zillow.com/homes/3168-Vista-Grande-92009_rb/
# status code received: 200
# 180035702 7087-Estrella-De-Mar-Rd-B-92009
# https://www.zillow.com/homes/7087-Estrella-De-Mar-Rd-B-92009_rb/
# status code received: 200
# 180036867 7083-Estrella-De-Mar-Rd-C-92009
# https://www.zillow.com/homes/7083-Estrella-De-Mar-Rd-C-92009_rb/
# status code received: 200
# 180043977 2311-Caringa-Way-44-92009
# https://www.zillow.com/homes/2311-Caringa-Way-44-92009_rb/
# status code received: 200
# 180023756 2504-Navarra-Drive-206-92009
# https://www.zillow.com/homes/2504-Navarra-Drive-206-92009_rb/
# status code received: 200
# 180041639 2323-Caringa-Way-16-92009
# https://www.zillow.com/homes/2323-Caringa-Way-16-92009_rb/
# status code received: 200
# 180030580 2319-Caringa-Way-58-92009
# https://www.zillow.com/homes/2319-Caringa-Way-58-92009_rb/
# status code received: 200
# 180038138 6526-Corte-Montecito-92009
# https://www.zillow.com/homes/6526-Corte-Montecito-92009_rb/
# status code received: 200
# 180040676 7727-Caminito-Monarca-108-92009
# https://www.zillow.com/homes/7727-Caminito-Monarca-108-92009_rb/
# status code received: 200
# 180046026 2353-Caringa-Way-1-92009
# https://www.zillow.com/homes/2353-Caringa-Way-1-92009_rb/
# status code received: 200
# 180040044 2854-Andover-Ave.-92010
# https://www.zillow.com/homes/2854-Andover-Ave.-92010_rb/
# status code received: 200
# 180046159 2903-Via-Carrio-92010
# https://www.zillow.com/homes/2903-Via-Carrio-92010_rb/
# status code received: 200
# 180031638 2866-Englewood-Way-92010
# https://www.zillow.com/homes/2866-Englewood-Way-92010_rb/
# status code received: 200
# 180046105 2810-Via-Magia-92010
# https://www.zillow.com/homes/2810-Via-Magia-92010_rb/
# status code received: 200
# 180044295 2615-Via-Eco-92010
# https://www.zillow.com/homes/2615-Via-Eco-92010_rb/
# status code received: 200
# 180038883 3703-Jetty-Pt-92010
# https://www.zillow.com/homes/3703-Jetty-Pt-92010_rb/
# status code received: 200
# 180034385 900-Caminito-Madrigal-A-92011
# https://www.zillow.com/homes/900-Caminito-Madrigal-A-92011_rb/
# status code received: 200
# 180039869 6573-Paseo-Del-Norte-C-92011
# https://www.zillow.com/homes/6573-Paseo-Del-Norte-C-92011_rb/
# status code received: 200
# 180031793 6575-Paseo-Del-Norte-F-92011
# https://www.zillow.com/homes/6575-Paseo-Del-Norte-F-92011_rb/
# status code received: 200
# 180046017 1844-Cottonwood-Ave-92011
# https://www.zillow.com/homes/1844-Cottonwood-Ave-92011_rb/
# status code received: 200
# 180044878 13778-Ruette-Le-Parc-C-92014
# https://www.zillow.com/homes/13778-Ruette-Le-Parc-C-92014_rb/
# status code received: 200
# 180035911 552-Canyon-Drive-24-92054
# https://www.zillow.com/homes/552-Canyon-Drive-24-92054_rb/
# status code received: 200
# 180041243 2821-MESA-92054
# https://www.zillow.com/homes/2821-MESA-92054_rb/
# status code received: 200
# 180041607 2166-Via-Robles-92054
# https://www.zillow.com/homes/2166-Via-Robles-92054_rb/
# status code received: 200
# 180032927 910-N-Pacific-Street-40-92054
# https://www.zillow.com/homes/910-N-Pacific-Street-40-92054_rb/
# status code received: 200
# 180043689 3538-Paseo-de-los-Americanos-129-92056
# https://www.zillow.com/homes/3538-Paseo-de-los-Americanos-129-92056_rb/
# status code received: 200
# 180036120 3528-Paseo-De-Los-Americanos-117-92056
# https://www.zillow.com/homes/3528-Paseo-De-Los-Americanos-117-92056_rb/
# status code received: 200
# 180040770 100-Sea-Cliff-Way-106-92056
# https://www.zillow.com/homes/100-Sea-Cliff-Way-106-92056_rb/
# status code received: 200
# 180044083 3555-Cameo-Dr-64-92056
# https://www.zillow.com/homes/3555-Cameo-Dr-64-92056_rb/
# status code received: 200
# 180035075 3897-Marvin-St-92056
# https://www.zillow.com/homes/3897-Marvin-St-92056_rb/
# status code received: 200
# 180027395 4329-Star-Path-Way-1-92056
# https://www.zillow.com/homes/4329-Star-Path-Way-1-92056_rb/
# status code received: 200
# 180044917 3160-Camino-Crest-Dr-92056
# https://www.zillow.com/homes/3160-Camino-Crest-Dr-92056_rb/
# status code received: 200
# 180039225 4212-Vista-Del-Rio-Way-7-92057
# https://www.zillow.com/homes/4212-Vista-Del-Rio-Way-7-92057_rb/
# status code received: 200
# 180038662 4250-VISTA-PANORAMA-201-92057
# https://www.zillow.com/homes/4250-VISTA-PANORAMA-201-92057_rb/
# status code received: 200
# 180039929 4054-Craven-Rd-50-92057
# https://www.zillow.com/homes/4054-Craven-Rd-50-92057_rb/
# status code received: 200
# 180037232 4034-Craven-Road-34-92057
# https://www.zillow.com/homes/4034-Craven-Road-34-92057_rb/
# status code received: 200
# 180037915 4228-Mission-Ranch-Way-92057
# https://www.zillow.com/homes/4228-Mission-Ranch-Way-92057_rb/
# status code received: 200
# 180031171 4233-Mission-Ranch-Way-92057
# https://www.zillow.com/homes/4233-Mission-Ranch-Way-92057_rb/
# status code received: 200
# 180044942 3481-Peach-Tree-Way-92058
# https://www.zillow.com/homes/3481-Peach-Tree-Way-92058_rb/
# status code received: 200
# 180039319 774-Timber-Cove-Way-92058
# https://www.zillow.com/homes/774-Timber-Cove-Way-92058_rb/
# status code received: 200
# 180024963 4261-Arcata-Bay-Way-92058
# https://www.zillow.com/homes/4261-Arcata-Bay-Way-92058_rb/
# status code received: 200
# 180029802 820-Malibu-Point-Way-92058
# https://www.zillow.com/homes/820-Malibu-Point-Way-92058_rb/
# status code received: 200
# 180042019 231-Blossom-Way-92058
# https://www.zillow.com/homes/231-Blossom-Way-92058_rb/
# status code received: 200
# 180042374 777-Abalone-Point-Way-92058
# https://www.zillow.com/homes/777-Abalone-Point-Way-92058_rb/
# status code received: 200
# 180042948 1640-10th-ave-307-92101
# https://www.zillow.com/homes/1640-10th-ave-307-92101_rb/
# status code received: 200
# 180039403 1643-6th-Avenue-104-92101
# https://www.zillow.com/homes/1643-6th-Avenue-104-92101_rb/
# status code received: 200
# 180032960 1225-Island-Ave-112-92101
# https://www.zillow.com/homes/1225-Island-Ave-112-92101_rb/
# status code received: 200
# 180045477 1501-Front-St-216-92101
# https://www.zillow.com/homes/1501-Front-St-216-92101_rb/
# status code received: 200
# 180037213 1640-10Th-Ave-308-92101
# https://www.zillow.com/homes/1640-10Th-Ave-308-92101_rb/
# status code received: 200
# 180045040 550-Park-Blvd-2202-92101
# https://www.zillow.com/homes/550-Park-Blvd-2202-92101_rb/
# status code received: 200
# 180032928 1514-7th-Ave.-101-92101
# https://www.zillow.com/homes/1514-7th-Ave.-101-92101_rb/
# status code received: 200
# 180042110 1501-Front-St-422-92101
# https://www.zillow.com/homes/1501-Front-St-422-92101_rb/
# status code received: 200
# 180036321 1150-J-Street-108-92101
# https://www.zillow.com/homes/1150-J-Street-108-92101_rb/
# status code received: 200
# 180044886 206-Park-Blvd-210-92101
# https://www.zillow.com/homes/206-Park-Blvd-210-92101_rb/
# status code received: 200
# 180044791 1281-34th-St-3-92102
# https://www.zillow.com/homes/1281-34th-St-3-92102_rb/
# status code received: 200
# 180028380 4854-Charles-Lews-Way-92102
# https://www.zillow.com/homes/4854-Charles-Lews-Way-92102_rb/
# status code received: 200
# 180046211 3775-Georgia-Street-306-92103
# https://www.zillow.com/homes/3775-Georgia-Street-306-92103_rb/
# status code received: 200
# 180038639 3606-1st-Avenue-101-92103
# https://www.zillow.com/homes/3606-1st-Avenue-101-92103_rb/
# status code received: 200
# 180043890 3666-3rd-Avenue-204-92103
# https://www.zillow.com/homes/3666-3rd-Avenue-204-92103_rb/
# status code received: 200
# 180036485 836-W-Pennsylvania-Ave-205-92103
# https://www.zillow.com/homes/836-W-Pennsylvania-Ave-205-92103_rb/
# status code received: 200
# 180044883 3782-DOVE-ST-92103
# https://www.zillow.com/homes/3782-DOVE-ST-92103_rb/
# status code received: 200
# 180045431 1289-Terracina-Ln-92103
# https://www.zillow.com/homes/1289-Terracina-Ln-92103_rb/
# status code received: 200
# 180041319 3939-Eagle-204-92103
# https://www.zillow.com/homes/3939-Eagle-204-92103_rb/
# status code received: 200
# 180040794 4080-Front-Street-204-92103
# https://www.zillow.com/homes/4080-Front-Street-204-92103_rb/
# status code received: 200
# 180032368 909-Sutter-Street-304-92103
# https://www.zillow.com/homes/909-Sutter-Street-304-92103_rb/
# status code received: 200
# 180034657 521-Arbor-Dr-202-92103
# https://www.zillow.com/homes/521-Arbor-Dr-202-92103_rb/
# status code received: 200
# 180040116 1950-Upas-St-101-92104
# https://www.zillow.com/homes/1950-Upas-St-101-92104_rb/
# status code received: 200
# 180044175 2828-University-Ave-201-92104
# https://www.zillow.com/homes/2828-University-Ave-201-92104_rb/
# status code received: 200
# 180037854 5231-Caminito-Mindy-92105
# https://www.zillow.com/homes/5231-Caminito-Mindy-92105_rb/
# status code received: 200
# 180045199 3460-39th-Street-C-92105
# https://www.zillow.com/homes/3460-39th-Street-C-92105_rb/
# status code received: 200
# 180028337 5404-Olive-St-C-92105
# https://www.zillow.com/homes/5404-Olive-St-C-92105_rb/
# status code received: 200
# 180040318 5244-Caminito-Cachorro-92105
# https://www.zillow.com/homes/5244-Caminito-Cachorro-92105_rb/
# status code received: 200
# 180044606 5404-Olive-St-B-92105
# https://www.zillow.com/homes/5404-Olive-St-B-92105_rb/
# status code received: 200
# 180045993 5319-Caminito-Cachorro-92105
# https://www.zillow.com/homes/5319-Caminito-Cachorro-92105_rb/
# status code received: 200
# 180045650 3042-Macaulay-92106
# https://www.zillow.com/homes/3042-Macaulay-92106_rb/
# status code received: 200
# 180046225 8079-Caminito-De-Pizza-F-92108
# https://www.zillow.com/homes/8079-Caminito-De-Pizza-F-92108_rb/
# status code received: 200
# 180023083 8085-Caminito-De-Pizza-R-92108
# https://www.zillow.com/homes/8085-Caminito-De-Pizza-R-92108_rb/
# status code received: 200
# 180043289 10425-Caminito-Cuervo-224-92108
# https://www.zillow.com/homes/10425-Caminito-Cuervo-224-92108_rb/
# status code received: 200
# 180042531 10300-Caminito-Cuervo-50-92108
# https://www.zillow.com/homes/10300-Caminito-Cuervo-50-92108_rb/
# status code received: 200
# 180045052 6717-Friars-Rd-91-92108
# https://www.zillow.com/homes/6717-Friars-Rd-91-92108_rb/
# status code received: 200
# 180043517 6363-Rancho-Mission-Road-4-92108
# https://www.zillow.com/homes/6363-Rancho-Mission-Road-4-92108_rb/
# status code received: 200
# 180038861 2188-Gill-Village-Way-812-92108
# https://www.zillow.com/homes/2188-Gill-Village-Way-812-92108_rb/
# status code received: 200
# 180045243 10325-Caminito-Cuervo-193-92108
# https://www.zillow.com/homes/10325-Caminito-Cuervo-193-92108_rb/
# status code received: 200
# 180045012 2002-Missouri-St-6-92109
# https://www.zillow.com/homes/2002-Missouri-St-6-92109_rb/
# status code received: 200
# 180041763 1855-Diamond-St-113-92109
# https://www.zillow.com/homes/1855-Diamond-St-113-92109_rb/
# status code received: 200
# 180042068 4600-Lamont-4-127-92109
# https://www.zillow.com/homes/4600-Lamont-4-127-92109_rb/
# status code received: 200
# 180045668 4809-Bella-Pacific-Row-102-92109
# https://www.zillow.com/homes/4809-Bella-Pacific-Row-102-92109_rb/
# status code received: 200
# 180041438 4833-Bella-Pacific-222-92109
# https://www.zillow.com/homes/4833-Bella-Pacific-222-92109_rb/
# status code received: 200
# 180035443 5790-Friars-Rd-E4-92110
# https://www.zillow.com/homes/5790-Friars-Rd-E4-92110_rb/
# status code received: 200
# 180044768 5780-Friars-B2-92110
# https://www.zillow.com/homes/5780-Friars-B2-92110_rb/
# status code received: 200
# 180045017 3845-Groton-St-3-92110
# https://www.zillow.com/homes/3845-Groton-St-3-92110_rb/
# status code received: 200
# 180033113 1055-Donahue-7-92110
# https://www.zillow.com/homes/1055-Donahue-7-92110_rb/
# status code received: 200
# 180025703 5645-Friars-350-92110
# https://www.zillow.com/homes/5645-Friars-350-92110_rb/
# status code received: 200
# 180023022 5722-Riley-Street-5-92110
# https://www.zillow.com/homes/5722-Riley-Street-5-92110_rb/
# status code received: 200
# 180040138 3471-Coastline-92110
# https://www.zillow.com/homes/3471-Coastline-92110_rb/
# status code received: 200
# 180045948 4070-Loma-Riviera-Circle-92110
# https://www.zillow.com/homes/4070-Loma-Riviera-Circle-92110_rb/
# status code received: 200
# 180045566 3465-Coastline-Pl-92110
# https://www.zillow.com/homes/3465-Coastline-Pl-92110_rb/
# status code received: 200
# 180045269 4147-Loma-Riviera-Ln-92110
# https://www.zillow.com/homes/4147-Loma-Riviera-Ln-92110_rb/
# status code received: 200
# 180044849 4239-Loma-Riviera-Ln-92110
# https://www.zillow.com/homes/4239-Loma-Riviera-Ln-92110_rb/
# status code received: 200
# 180038466 3264-Loma-Riviera-Dr-92110
# https://www.zillow.com/homes/3264-Loma-Riviera-Dr-92110_rb/
# status code received: 200
# 180041827 3204-Loma-Riviera-Dr-92110
# https://www.zillow.com/homes/3204-Loma-Riviera-Dr-92110_rb/
# status code received: 200
# 180044630 3747-Keating-Street-2-92110
# https://www.zillow.com/homes/3747-Keating-Street-2-92110_rb/
# status code received: 200
# 180036104 4104-Mount-Alifan-Place-D-92111
# https://www.zillow.com/homes/4104-Mount-Alifan-Place-D-92111_rb/
# status code received: 200
# 180045604 4140-Mount-Alifan-Pl-D-92111
# https://www.zillow.com/homes/4140-Mount-Alifan-Pl-D-92111_rb/
# status code received: 200
# 180040936 6555-Mount-Ada-Rd-222-92111
# https://www.zillow.com/homes/6555-Mount-Ada-Rd-222-92111_rb/
# status code received: 200
# 180044637 4169-Mount-Alifan-Place-B-92111
# https://www.zillow.com/homes/4169-Mount-Alifan-Place-B-92111_rb/
# status code received: 200
# 180044701 4198-Mount-Alifan-Pl-J-92111
# https://www.zillow.com/homes/4198-Mount-Alifan-Pl-J-92111_rb/
# status code received: 200
# 180039768 5570-Caminito-Roberto-92111
# https://www.zillow.com/homes/5570-Caminito-Roberto-92111_rb/
# status code received: 200
# 180045648 2042-Coolidge-St.-102-92111
# https://www.zillow.com/homes/2042-Coolidge-St.-102-92111_rb/
# status code received: 200
# 180033141 5605-Caminito-Katerina-92111
# https://www.zillow.com/homes/5605-Caminito-Katerina-92111_rb/
# status code received: 200
# 180045482 7224-Camino-Degrazia-260-92111
# https://www.zillow.com/homes/7224-Camino-Degrazia-260-92111_rb/
# status code received: 200
# 180044410 7099-Park-Mesa-Way-65-92111
# https://www.zillow.com/homes/7099-Park-Mesa-Way-65-92111_rb/
# status code received: 200
# 180042446 5522-Caminito-Katerina-92111
# https://www.zillow.com/homes/5522-Caminito-Katerina-92111_rb/
# status code received: 200
# 180028688 3988-Caminito-Patricia-92111
# https://www.zillow.com/homes/3988-Caminito-Patricia-92111_rb/
# status code received: 200
# 180043268 6373-Caminito-Salado-92111
# https://www.zillow.com/homes/6373-Caminito-Salado-92111_rb/
# status code received: 200
# 180036788 5386-Mount-Alifan-Dr-92111
# https://www.zillow.com/homes/5386-Mount-Alifan-Dr-92111_rb/
# status code received: 200
# 180046090 5204-Mount-Alifan-92111
# https://www.zillow.com/homes/5204-Mount-Alifan-92111_rb/
# status code received: 200
# 180045729 1149-S-41st-St-26-92113
# https://www.zillow.com/homes/1149-S-41st-St-26-92113_rb/
# status code received: 200
# 180042690 4300-Newton-Avenue-103-92113
# https://www.zillow.com/homes/4300-Newton-Avenue-103-92113_rb/
# status code received: 200
# 180039990 425-S-Meadowbrook-Dr-129-92114
# https://www.zillow.com/homes/425-S-Meadowbrook-Dr-129-92114_rb/
# status code received: 200
# 180043171 4897-Collwood-Blvd-A-92115
# https://www.zillow.com/homes/4897-Collwood-Blvd-A-92115_rb/
# status code received: 200
# 180039673 4534-60th-115-92115
# https://www.zillow.com/homes/4534-60th-115-92115_rb/
# status code received: 200
# 180040943 3980-FAIRCROSS-PL-11-92115
# https://www.zillow.com/homes/3980-FAIRCROSS-PL-11-92115_rb/
# status code received: 200
# 180041957 5985-Dandridge-Lane-98-92115
# https://www.zillow.com/homes/5985-Dandridge-Lane-98-92115_rb/
# status code received: 200
# 180044517 3926-60Th-St-180-92115
# https://www.zillow.com/homes/3926-60Th-St-180-92115_rb/
# status code received: 200
# 180033506 4108-Collwood-Lane-92115
# https://www.zillow.com/homes/4108-Collwood-Lane-92115_rb/
# status code received: 200
# 180030679 2323-Adams-Ave-106-92116
# https://www.zillow.com/homes/2323-Adams-Ave-106-92116_rb/
# status code received: 200
# 180040560 4733-W-Mountain-View-Dr-2-92116
# https://www.zillow.com/homes/4733-W-Mountain-View-Dr-2-92116_rb/
# status code received: 200
# 180026599 5170-Clairemont-Mesa-Boulevard-17-92117
# https://www.zillow.com/homes/5170-Clairemont-Mesa-Boulevard-17-92117_rb/
# status code received: 200
# 180039952 4459-Clairemont-Drive-B-92117
# https://www.zillow.com/homes/4459-Clairemont-Drive-B-92117_rb/
# status code received: 200
# 180037637 3505-Monair-Dr-A-92117
# https://www.zillow.com/homes/3505-Monair-Dr-A-92117_rb/
# status code received: 200
# 180036997 2727-Morena-Blvd-206-92117
# https://www.zillow.com/homes/2727-Morena-Blvd-206-92117_rb/
# status code received: 200
# 180021569 3707-Balboa-Terrace-A-92117
# https://www.zillow.com/homes/3707-Balboa-Terrace-A-92117_rb/
# status code received: 200
# 180044531 4166-Balboa-Way-92117
# https://www.zillow.com/homes/4166-Balboa-Way-92117_rb/
# status code received: 200
# 180022762 6930-Hyde-Park-Dr.-106-92119
# https://www.zillow.com/homes/6930-Hyde-Park-Dr.-106-92119_rb/
# status code received: 200
# 180040206 6868-Hyde-Park-Dr-M-92119
# https://www.zillow.com/homes/6868-Hyde-Park-Dr-M-92119_rb/
# status code received: 200
# 180042766 6816-Hyde-Park-Dr-Unit-N-92119
# https://www.zillow.com/homes/6816-Hyde-Park-Dr-Unit-N-92119_rb/
# status code received: 200
# 180046246 6816-Hyde-Park-Dr-O-92119
# https://www.zillow.com/homes/6816-Hyde-Park-Dr-O-92119_rb/
# status code received: 200
# 180046316 6924-Hyde-Park-Dr.-317-92119
# https://www.zillow.com/homes/6924-Hyde-Park-Dr.-317-92119_rb/
# status code received: 200
# 180043685 7245-Navajo-Road-120D-92119
# https://www.zillow.com/homes/7245-Navajo-Road-120D-92119_rb/
# status code received: 200
# 180045641 6851-CAMINITO-MONTANOSO-6-92119
# https://www.zillow.com/homes/6851-CAMINITO-MONTANOSO-6-92119_rb/
# status code received: 200
# 180046014 5503-Adobe-Falls-Rd-1-92120
# https://www.zillow.com/homes/5503-Adobe-Falls-Rd-1-92120_rb/
# status code received: 200
# 180033040 5493-Adobe-Falls-Rd-3-92120
# https://www.zillow.com/homes/5493-Adobe-Falls-Rd-3-92120_rb/
# status code received: 200
# 180036689 7677-Mission-Gorge-Rd-137-92120
# https://www.zillow.com/homes/7677-Mission-Gorge-Rd-137-92120_rb/
# status code received: 200
# 180041454 7677-Mission-Gorge-Rd-139-92120
# https://www.zillow.com/homes/7677-Mission-Gorge-Rd-139-92120_rb/
# status code received: 200
# 180041758 5577-Adobe-Falls-Road-D-92120
# https://www.zillow.com/homes/5577-Adobe-Falls-Road-D-92120_rb/
# status code received: 200
# 180042957 5661-Adobe-Falls-Rd-B-92120
# https://www.zillow.com/homes/5661-Adobe-Falls-Rd-B-92120_rb/
# status code received: 200
# 180044450 7944-Mission-Vista-Drive-92120
# https://www.zillow.com/homes/7944-Mission-Vista-Drive-92120_rb/
# status code received: 200
# 180045543 8308-Regents-Rd-1C-92122
# https://www.zillow.com/homes/8308-Regents-Rd-1C-92122_rb/
# status code received: 200
# 180031368 4060-Rosenda-Court-228-92122
# https://www.zillow.com/homes/4060-Rosenda-Court-228-92122_rb/
# status code received: 200
# 180033079 7837-Camino-Glorita-92122
# https://www.zillow.com/homes/7837-Camino-Glorita-92122_rb/
# status code received: 200
# 180045108 9229-Village-Glen-Dr-231-92123
# https://www.zillow.com/homes/9229-Village-Glen-Dr-231-92123_rb/
# status code received: 200
# 180045670 9651-WEST-CANYON-TERRACE-2-92123
# https://www.zillow.com/homes/9651-WEST-CANYON-TERRACE-2-92123_rb/
# status code received: 200
# 180043119 8744-Esplanade-Park-Lane-92123
# https://www.zillow.com/homes/8744-Esplanade-Park-Lane-92123_rb/
# status code received: 200
# 180044780 5838-Mission-Center-Road-C-92123
# https://www.zillow.com/homes/5838-Mission-Center-Road-C-92123_rb/
# status code received: 200
# 180042479 11233-Tierrasanta-Blvd-33-92124
# https://www.zillow.com/homes/11233-Tierrasanta-Blvd-33-92124_rb/
# status code received: 200
# 180039889 11255-Tierrasanta-Blvd-117-92124
# https://www.zillow.com/homes/11255-Tierrasanta-Blvd-117-92124_rb/
# status code received: 200
# 180043526 10810-Macouba-Pl-92124
# https://www.zillow.com/homes/10810-Macouba-Pl-92124_rb/
# status code received: 200
# 180045714 11332-Portobelo-Dr-3-92124
# https://www.zillow.com/homes/11332-Portobelo-Dr-3-92124_rb/
# status code received: 200
# 180044385 5361-Oakleaf-92124
# https://www.zillow.com/homes/5361-Oakleaf-92124_rb/
# status code received: 200
# 180041149 9938-Pineknoll-Lane-92124
# https://www.zillow.com/homes/9938-Pineknoll-Lane-92124_rb/
# status code received: 200
# 180037442 9415-Gold-Coast-Dr.-B8-92126
# https://www.zillow.com/homes/9415-Gold-Coast-Dr.-B8-92126_rb/
# status code received: 200
# 180043265 9710-Mesa-Springs-Way-1-92126
# https://www.zillow.com/homes/9710-Mesa-Springs-Way-1-92126_rb/
# status code received: 200
# 180038852 10109-Caminito-Mulege-92126
# https://www.zillow.com/homes/10109-Caminito-Mulege-92126_rb/
# status code received: 200
# 180044068 9423-GOLD-COAST-C4-92126
# https://www.zillow.com/homes/9423-GOLD-COAST-C4-92126_rb/
# status code received: 200
# 180045155 11575-CAMINITO-LA-BAR-27-92126
# https://www.zillow.com/homes/11575-CAMINITO-LA-BAR-27-92126_rb/
# status code received: 200
# 180044959 7369-Calle-Cristobal-206-92126
# https://www.zillow.com/homes/7369-Calle-Cristobal-206-92126_rb/
# status code received: 200
# 180010615 10512-Caminito-Westchester-92126
# https://www.zillow.com/homes/10512-Caminito-Westchester-92126_rb/
# status code received: 200
# 180042157 9524-Caminito-Toga-92126
# https://www.zillow.com/homes/9524-Caminito-Toga-92126_rb/
# status code received: 200
# 180040308 13338-Via-Magdalena-1-92129
# https://www.zillow.com/homes/13338-Via-Magdalena-1-92129_rb/
# status code received: 200
# 180042779 12221-Carmel-Vista-Rd-104-92130
# https://www.zillow.com/homes/12221-Carmel-Vista-Rd-104-92130_rb/
# status code received: 200
# 180043108 9917-Scripps-Westview-Way-120-92131
# https://www.zillow.com/homes/9917-Scripps-Westview-Way-120-92131_rb/
# status code received: 200
# 180045679 10563-Caminito-Memosac-92131
# https://www.zillow.com/homes/10563-Caminito-Memosac-92131_rb/
# status code received: 200
# 180044462 11011-Scripps-Ranch-92131
# https://www.zillow.com/homes/11011-Scripps-Ranch-92131_rb/
# status code received: 200
# 180043231 6520-Omega-Dr-92139
# https://www.zillow.com/homes/6520-Omega-Dr-92139_rb/
# status code received: 200
# 180044974 6852-Panamint-Row-92139
# https://www.zillow.com/homes/6852-Panamint-Row-92139_rb/
# status code received: 200
# 180045386 7438-Tooma-St-155-92139
# https://www.zillow.com/homes/7438-Tooma-St-155-92139_rb/
# status code received: 200
# 180040418 6830-Parkside-Ave-92139
# https://www.zillow.com/homes/6830-Parkside-Ave-92139_rb/
# status code received: 200
# 180033477 6856-Quebec-Ct-4-92139
# https://www.zillow.com/homes/6856-Quebec-Ct-4-92139_rb/
# status code received: 200
# 180044133 6840-Panamint-Row-3-92139
# https://www.zillow.com/homes/6840-Panamint-Row-3-92139_rb/
# status code received: 200
# 180046339 6829-Panamint-Row-3-92139
# https://www.zillow.com/homes/6829-Panamint-Row-3-92139_rb/
# status code received: 200
# 180038440 1753-Manzana-Way-92139
# https://www.zillow.com/homes/1753-Manzana-Way-92139_rb/
# status code received: 200
# 180040347 6767-Parkside-Ave-92139
# https://www.zillow.com/homes/6767-Parkside-Ave-92139_rb/
# status code received: 200
# 180045664 1888-Manzana-Way-92139
# https://www.zillow.com/homes/1888-Manzana-Way-92139_rb/
# status code received: 200
# 180031364 1899-Manzana-Way-4-92139
# https://www.zillow.com/homes/1899-Manzana-Way-4-92139_rb/
# status code received: 200
# 180027966 7076-Attleborough-Ct-92139
# https://www.zillow.com/homes/7076-Attleborough-Ct-92139_rb/
# status code received: 200
# 180045640 1886-Manzana-Way-92139
# https://www.zillow.com/homes/1886-Manzana-Way-92139_rb/
# status code received: 200
# 180044441 7019-DEERHURST-CT-92139
# https://www.zillow.com/homes/7019-DEERHURST-CT-92139_rb/
# status code received: 200
# 180044784 2233-Manzana-Way-92139
# https://www.zillow.com/homes/2233-Manzana-Way-92139_rb/
# status code received: 200
# 180040324 24374-Larchmont-Ct-69-92653
# https://www.zillow.com/homes/24374-Larchmont-Ct-69-92653_rb/
# status code received: 200
# 180042450 25185-Via-Terracina-92677
# https://www.zillow.com/homes/25185-Via-Terracina-92677_rb/
# status code received: 200
# 180035417 3575-Cameo-Drive-43-92056
# https://www.zillow.com/homes/3575-Cameo-Drive-43-92056_rb/
# status code received: 200
# Writing data to output file
